# %% [markdown]
# ## 作業
#
# 1. 如何使用已經訓練好的模型？
# 2. 依照 https://github.com/qqwweee/keras-yolo3 的程式碼，請敘述，訓練模型時，資料集的格式是什麼？具體一點的說，要提供什麼格式的文件來描述資料集的圖片以及 bboxes 的信息呢？

# %% [markdown]
# 1. Ans: 執行 python convert.py -w yolov3.cfg yolov3.weights model_data/yolo_weights.h5 將預先訓練好的模型轉成 keras 能讀的 h5 模型權重。
#
# 2. Ans:資料集的格式分為圖檔(image)、種類名稱檔(class names file)和標註檔(annotation file) 圖檔: 就是一般的圖片。 標註檔: 每一列開頭為圖片的路徑 接著為該圖中各物件bounding box的座標及總類， 各bounding box之間以空格分開， bounding box內的座標、種類資訊則由","分隔，不可用空格。 種類名稱檔: 全檔只有一列，列出所有種類的名稱，各類間以空格分隔。

# %%
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: `1.x` or `2.x`.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.0

# %%
pip install keras==2.2.4 # 需要安裝 keras 2.2.4 的版本
# Out:
# ...
#      |████████████████████████████████| 317kB 3.4MB/s
# ...
#   Found existing installation: Keras 2.2.5
#     Uninstalling Keras-2.2.5:
#       Successfully uninstalled Keras-2.2.5
# ...

# %%
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# 下載基於 keras 的 yolov3 程式碼
# %cd 'gdrive/My Drive'
# !git clone https://github.com/qqwweee/keras-yolo3 # 如果之前已經下載過就可以註解掉
# %cd keras-yolo3
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive
# /content/gdrive/My Drive/keras-yolo3

# %%
from PIL import Image
image = Image.open('dog.jpg')
